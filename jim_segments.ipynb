# %%
from segment import segment
import os

# %%
model_path = r"D:\Research\Isaacs Lab\DeepAxon\models\model_10img_16bs-200epoch.keras"
output_path = r"D:\Research\Isaacs Lab\DeepAxon\Control Confirmation"
img_dir = r"D:\Research\Isaacs Lab\DeepAxon\Control Confirmation\resized"

# %%
for img in os.listdir(img_dir):
    img_path = os.path.join(img_dir, img)
    segment(img_path, model_path, output_path)
# Out:
# ...
# 1/1 [==============================] - 0s 326ms/step
# ...
# ...
# 1/1 [==============================] - 1s 682ms/step
