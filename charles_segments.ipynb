# %%
from segment import segment
import os

# %%
dir = r"D:\Research\Isaacs Lab\DeepAxon\Charles Image DA Seg\Original"
model = r"D:\Research\Isaacs Lab\DeepAxon\models\model_10img_16bs-200epoch.keras"
output_path = r"D:\Research\Isaacs Lab\DeepAxon\Charles Image DA Seg\Segmented"

# %%
for img in os.listdir(dir):
    img_path = os.path.join(dir, img)
    segment(img_path, model, output_path)
# Out:
# ...
# 1/1 [==============================] - 0s 158ms/step
# ...
# ...
# 1/1 [==============================] - 0s 203ms/step
